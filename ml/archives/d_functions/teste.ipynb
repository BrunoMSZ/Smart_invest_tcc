# %%
import pandas as pd

df = pd.read_parquet(r"E:\TCC\data\raw\dataset_final.parquet")
print(df['ticker'].unique())
# Out:
# <ArrowStringArray>
# [  'PETR4T',   'VALE5T',   'OGXP3T',   'ECOD3T',   'PDGR3T',   'BRKM5T',
#    'PLAS3T',   'CSNA3T',   'PMAM3T',   'GGBR4T',
#  ...
#  'IRBRM455', 'AZULN265',  'BRAVQ32', 'CSANM930', 'CSANN710', 'WEGEM567',
#  'RAILM212', 'BBASN232', 'BBASA251', 'RDORN290']
# Length: 114252, dtype: str
